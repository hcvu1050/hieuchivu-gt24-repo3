# %%
import sys
sys.path.append ('..')
from src.models.model1.recommend import extract_technique_branch

# %%
submodel = extract_technique_branch ('m06c_test1')

# %%
submodel.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_technique_data_sources (  [(None, None)]      0           []
#  InputLayer)
#
#  input_technique_detection_name  [(None, None)]      0           []
#   (InputLayer)
#
#  input_technique_mitigation_id   [(None, None)]      0           []
#  (InputLayer)
#
#  input_technique_platforms (Inp  [(None, None)]      0           []
#  utLayer)
#
#  input_technique_software_id (I  [(None, None)]      0           []
#  nputLayer)
#
#  input_technique_tactics (Input  [(None, None)]      0           []
#  Layer)
#
#  vectorize_technique_data_sourc  (None, None)        0           ['input_technique_data_sources[0]
#  es (TextVectorization)                                          [0]']
#
#  vectorize_technique_detection_  (None, None)        0           ['input_technique_detection_name[
# ...
