# %%
import pandas as pd

# %%
group_df = pd.read_pickle ('../data/interim/X_group_org.pkl')

# %%
group_df
# Out:
#     group_ID                            input_group_software_id  \
# 0      G0099                                            [s0434]
# 1      G0006  [s0017, s0025, s0119, s0026, s0121, s0002, s00...
# 2      G0005                              [s0040, s0015, s0003]
# 3      G0023                                            [s0064]
# 4      G0025                                            [s0069]
# ..       ...                                                ...
# 131    G0044                              [s0501, s0013, s0141]
# 132    G0102  [s0552, s0534, s0521, s0154, s0575, s0024, s03...
# 133    G0128                                                 []
# 134    G0018  [s0043, s0042, s0039, s0012, s0096, s0100, s0104]
# 135    G0045  [s0552, s0144, s0154, s0624, s0152, s0628, s03...
#
#                                input_group_description
# 0    APT-C-36 is a suspected South America espionag...
# 1    APT1 is a Chinese threat group that has been a...
# ...

# %%
technique_df = pd.read_pickle ('../data/interim/X_technique_org.pkl')

# %%
technique_df
# Out:
#     technique_ID input_technique_platforms  \
# 0          T1548   [linux, windows, macos]
# 1      T1548.002                 [windows]
# 2      T1548.004                   [macos]
# 3      T1548.001            [linux, macos]
# 4      T1548.003            [linux, macos]
# ..           ...                       ...
# 602    T1102.002   [linux, windows, macos]
# 603    T1102.001   [linux, windows, macos]
# 604    T1102.003   [linux, windows, macos]
# 605        T1047                 [windows]
# 606        T1220                 [windows]
#
#                      input_technique_tactics  \
# 0    [defense_evasion, privilege_escalation]
# 1    [defense_evasion, privilege_escalation]
# 2    [defense_evasion, privilege_escalation]
# 3    [defense_evasion, privilege_escalation]
# 4    [defense_evasion, privilege_escalation]
# ..                                       ...
# 602                    [command_and_control]
# 603                    [command_and_control]
# ...
